# %% [markdown]
# # Subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# We can create subplots by passing parameters into the subplot function.
# it will return a fugure and a 2d array of axes
#
# parameters
# `ncols`, `nrows`
#
# you can set the size using `figsize`

# %%
num_rows =2
num_cols = 3
fig, axs = plt.subplots(ncols= num_cols, nrows=num_rows, figsize=(8,4))
for row in range(num_rows):
     for col in range(num_cols):
            axs[row, col].annotate(f"axs[{row},{col}]", (0.5,0.5), ha="center")

plt.show()

# %% [markdown]
# ### Example

# %%
data = [
    [2,4,5,6,3,5,6,7],
    [9,8,7,6,5,4,3,2],
    [1,2,3,4,5,6,7,8],
    [5,5,5,5,5,5,5,5]
]
x = 0.5 + np.arange(8)

# %%
num_rows =2
num_cols = 2
fig, axs = plt.subplots(ncols= num_cols, nrows=num_rows, figsize=(8,4))
count = 0
for row in range(num_rows):
     for col in range(num_cols):
            axs[row, col].plot(x, data[count])
            count += 1

plt.show()
